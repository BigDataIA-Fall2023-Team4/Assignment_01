# %%
# !pip install diagrams
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.4/24.4 MB 20.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.7/824.7 kB 50.8 MB/s eta 0:00:00
# ...

# %%
from diagrams import Cluster, Diagram, Edge
from diagrams.custom import Custom
from diagrams.programming.language import Python

with Diagram("Report", show=False) as diag:
    user = Custom("User", "/content/user.png")
    streamlit_dashboard = Custom("Streamlit Dashboard", "/content/streamlit logo.png")
    python = Python("Python Code")
    ydata_profiling = Custom("Ydata-Profiling", "/content/ydata_profiling_logo.png")
    gx = Custom("Great Expectations", "/content/gx.png")
    end_user = Custom("User", "/content/user.png")
    github = Custom("GitHub", "/content/github_logo.png")
    streamlit = Custom("Streamlit Dashboard", "/content/streamlit logo.png")

    user >> Edge(label = "Uploading a PDF") >> streamlit_dashboard
    streamlit_dashboard >> Edge(label = "Profiling") >> ydata_profiling
    streamlit_dashboard >> Edge(label = "Data Validation") >> gx
    ydata_profiling >> Edge(label = "Calling Python Function") >> python
    gx >> Edge(label = "Expectation Suite Hosted") >> github >> Edge(label = "Calling Python Function") >> python
    python >> Edge(label = "Report Generated") >> streamlit >> Edge(label = "Downloaded Report") >> end_user

diag
